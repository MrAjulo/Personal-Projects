# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
data = pd.read_csv('soccer.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
data.tail(5)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data.to_string(line_width=60)
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
data['Name'].value_counts()
# Out:
# J. Rodríguez           11
# Paulinho                8
# R. Williams             7
# J. Williams             7
# J. Valencia             6
# J. Gómez                6
# Felipe                  6
# J. Hernández            6
# M. Smith                5
# L. Rodríguez            5
# A. Traoré               5
# Danilo                  5
# J. Jones                5
# M. Gómez                5
# M. Pedersen             5
# J. Murillo              5
# J. Pérez                5
# D. Williams             5
# L. López                5
# J. Martínez             5
# J. Torres               5
# J. García               4
# L. Martínez             4
# Fernando                4
# J. Aguirre              4
# M. García               4
# Y. Kobayashi            4
# M. Dembélé              4
# L. Kelly                4
# R. Taylor               4
#                        ..
# L. Hoyos                1
# J. Carolina             1
# Manu Morlanes           1
# B. Stuver               1
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Loaned From             16943
# LWB                      2085
# LM                       2085
# CB                       2085
# LCB                      2085
# LB                       2085
# RWB                      2085
# RDM                      2085
# CDM                      2085
# LDM                      2085
# RM                       2085
# RCM                      2085
# CM                       2085
# LCM                      2085
# RAM                      2085
# RB                       2085
# CAM                      2085
# LAM                      2085
# RW                       2085
# RF                       2085
# CF                       2085
# LF                       2085
# LW                       2085
# RS                       2085
# ST                       2085
# LS                       2085
# RCB                      2085
# Release Clause           1564
# Joined                   1553
# Contract Valid Until      289
#                         ...
# ...

# %%
# the Loaned from column would be dropped because it has large amount of missing values
data.drop(columns =['Loaned From'], inplace=True)

# %%
data['LS']
# Out:
# 0        88+2
# 1        91+3
# 2        84+3
# 3         NaN
# 4        82+3
# 5        83+3
# 6        77+3
# 7        87+5
# 8        73+3
# 9         NaN
# 10       87+3
# 11       78+3
# 12       64+3
# 13       77+3
# 14       72+3
# 15       83+3
# 16       86+3
# 17       86+3
# 18        NaN
# 19        NaN
# 20       71+3
# 21       85+3
# 22        NaN
# 23       86+3
# 24       58+3
# 25       85+3
# 26       83+3
# 27       72+3
# 28       80+3
# 29       78+3
#          ...
# 18177    47+2
# 18178     NaN
# 18179    34+2
# 18180     NaN
# 18181    44+2
# 18182    40+2
# 18183     NaN
# 18184    41+2
# 18185    43+2
# 18186    43+2
# 18187    46+2
# 18188    45+2
# 18189    45+2
# 18190    42+2
# 18191    39+2
# 18192    44+2
# 18193    35+2
# 18194     NaN
# 18195    44+2
# 18196    40+2
# 18197    45+2
# 18198     NaN
# 18199    42+2
# 18200    45+2
# 18201    32+2
# 18202    42+2
# 18203    45+2
# 18204    45+2
# 18205    47+2
# 18206    43+2
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183    False
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# ...

# %%
data.drop_duplicates()
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
data.drop(columns=['Unnamed: 0', 'Photo', 'Flag', 'Club Logo'], inplace = True)

# %%
data.head(5)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  Special  ... Composure  Marking  \
# 0         FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# 1             Juventus     €77M  €405K     2228  ...      95.0     28.0
# 2  Paris Saint-Germain  €118.5M  €290K     2143  ...      94.0     27.0
# 3    Manchester United     €72M  €260K     1471  ...      68.0     15.0
# 4      Manchester City    €102M  €355K     2281  ...      88.0     68.0
#
#    StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %%
# TOp ten most popular country
data['Nationality'].value_counts().head(10)
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
# Top ten best players based on overall rating
data[(data['Overall']>90)].sort_values('Overall' ,ascending=False)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
#
#                   Club    Value   Wage  Special  ... Composure  Marking  \
# 0         FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# 1             Juventus     €77M  €405K     2228  ...      95.0     28.0
# 2  Paris Saint-Germain  €118.5M  €290K     2143  ...      94.0     27.0
# ...

# %%
# top ten clubs 
data['Club'].value_counts().head(10)
# Out:
# Liverpool              33
# FC Barcelona           33
# Fortuna Düsseldorf     33
# AS Monaco              33
# TSG 1899 Hoffenheim    33
# Borussia Dortmund      33
# Atlético Madrid        33
# Real Madrid            33
# Empoli                 33
# Eintracht Frankfurt    33
# Name: Club, dtype: int64

# %%
data.corr()
# Out:
#                                 ID       Age   Overall  Potential   Special  \
# ID                        1.000000 -0.739208 -0.417025   0.047074 -0.231352
# Age                      -0.739208  1.000000  0.452350  -0.253312  0.236695
# Overall                  -0.417025  0.452350  1.000000   0.660939  0.606960
# Potential                 0.047074 -0.253312  0.660939   1.000000  0.383727
# Special                  -0.231352  0.236695  0.606960   0.383727  1.000000
# International Reputation -0.356191  0.253765  0.499491   0.372993  0.292208
# Weak Foot                -0.075784  0.059867  0.212015   0.162346  0.341855
# Skill Moves              -0.056914  0.027649  0.414463   0.354290  0.763412
# Jersey Number             0.182074 -0.241156 -0.218931  -0.010474 -0.133716
# Crossing                 -0.131994  0.130545  0.394972   0.246319  0.866417
# Finishing                -0.082323  0.068660  0.332515   0.243355  0.724244
# ...

# %%
#HEad to HEad MEssi VS Ronaldo
messi = data.iloc[0]
ronaldo = data.iloc[1]
messiVSronaldo = pd.concat([messi,ronaldo], axis =1)
messiVSronaldo
# Out:
#                                        0                  1
# ID                                158023              20801
# Name                            L. Messi  Cristiano Ronaldo
# Age                                   31                 33
# Nationality                    Argentina           Portugal
# Overall                               94                 94
# Potential                             94                 94
# Club                        FC Barcelona           Juventus
# Value                            €110.5M               €77M
# Wage                               €565K              €405K
# Special                             2202               2228
# Preferred Foot                      Left              Right
# International Reputation               5                  5
# Weak Foot                              4                  4
# Skill Moves                            4                  5
# Work Rate                 Medium/ Medium          High/ Low
# ...

# %%
#Average age of players

average_age = data.Age.mean()
average_age
# Out:
# 25.122205745043114

# %%
data.Age.plot(kind= 'hist', bins= 50, figsize = (12,12), color= 'orange')
plt.show()

# %%
# list of players with potential
data[(data['Potential']>90)].sort_values('Potential' ,ascending=False)
# Out:
#           ID               Name  Age  Nationality  Overall  Potential  \
# 25    231747          K. Mbappé   19       France       88         95
# 0     158023           L. Messi   31    Argentina       94         94
# 1      20801  Cristiano Ronaldo   33     Portugal       94         94
# 15    211110          P. Dybala   24    Argentina       89         94
# 2     190871          Neymar Jr   26       Brazil       92         93
# 3     193080             De Gea   27        Spain       91         93
# 229   230621      G. Donnarumma   19        Italy       82         93
# 9     200389           J. Oblak   25     Slovenia       90         93
# 156   230666      Gabriel Jesus   21       Brazil       83         92
# 155   231443         O. Dembélé   21       France       83         92
# 79    220834      Marco Asensio   22        Spain       85         92
# 77    232363        M. Škriniar   23     Slovakia       85         92
# ...

# %%
Nigerian = data.Nationality == 'Nigeria'
data[Nigerian]
# Out:
#            ID             Name  Age Nationality  Overall  Potential  \
# 425    226790         W. Ndidi   21     Nigeria       80         85
# 789    213655         A. Iwobi   22     Nigeria       78         84
# 858    172962         V. Moses   27     Nigeria       78         78
# 1022   185195        O. Ighalo   29     Nigeria       77         77
# 1296   234045      H. Onyekuru   21     Nigeria       76         86
# 1531   229092          A. Umar   23     Nigeria       76         81
# 1550   216820         M. Simon   22     Nigeria       76         82
# 1615   188182       L. Balogun   30     Nigeria       75         75
# 1701   209984           M. Agu   25     Nigeria       75         80
# 1754   201818          A. Musa   25     Nigeria       75         77
# 1942   202934         O. Onazi   25     Nigeria       75         78
# 1946   225719     K. Iheanacho   21     Nigeria       75         83
# 2179   193337           J. Obi   27     Nigeria       74         75
# ...

# %%
# create a table of players with their club and postion 
name = data['Name']
position = data['Position']
club = data['Club']
overall = data['Overall']
data1 = pd.concat([name,position, club, overall], axis= 1)
data1.head(10)
# Out:
#                 Name Position                 Club  Overall
# 0           L. Messi       RF         FC Barcelona       94
# 1  Cristiano Ronaldo       ST             Juventus       94
# 2          Neymar Jr       LW  Paris Saint-Germain       92
# 3             De Gea       GK    Manchester United       91
# 4       K. De Bruyne      RCM      Manchester City       91
# 5          E. Hazard       LF              Chelsea       91
# 6          L. Modrić      RCM          Real Madrid       91
# 7          L. Suárez       RS         FC Barcelona       91
# 8       Sergio Ramos      RCB          Real Madrid       91
# 9           J. Oblak       GK      Atlético Madrid       90

# %%
#players with sprint speed and dribbling 
data[(data['SprintSpeed']> 90) & (data['Dribbling']>85)]
# Out:
#           ID               Name  Age  Nationality  Overall  Potential  \
# 1      20801  Cristiano Ronaldo   33     Portugal       94         94
# 25    231747          K. Mbappé   19       France       88         95
# 26    209331           M. Salah   26        Egypt       88         89
# 36    173731            G. Bale   28        Wales       88         88
# 55    222492            L. Sané   22      Germany       86         92
# 58    208722            S. Mané   26      Senegal       86         87
# 60    202652        R. Sterling   23      England       86         89
# 65    190483      Douglas Costa   27       Brazil       86         86
# 129   193082        J. Cuadrado   30     Colombia       84         84
# 155   231443         O. Dembélé   21       France       83         92
# 164   213345           K. Coman   22       France       83         87
# 270   198717            W. Zaha   25  Ivory Coast       82         85
# ...

# %%
data[(data['FKAccuracy']>90) & (data['LongShots']>85)]
# Out:
#        ID      Name  Age Nationality  Overall  Potential          Club  \
# 0  158023  L. Messi   31   Argentina       94         94  FC Barcelona
#
#      Value   Wage  Special  ... Composure  Marking  StandingTackle  \
# 0  €110.5M  €565K     2202  ...      96.0     33.0            28.0
#
#    SlidingTackle GKDiving GKHandling GKKicking GKPositioning  GKReflexes  \
# 0           26.0      6.0       11.0      15.0          14.0         8.0
#
#   Release Clause
# 0        €226.5M
#
# [1 rows x 84 columns]

# %%
#Looking to buy some quality young players? these are top ten
data[(data['Potential']>80) & (data['Age']<= 19)].head(10)
# Out:
#           ID                 Name  Age    Nationality  Overall  Potential  \
# 25    231747            K. Mbappé   19         France       88         95
# 226   235243           M. de Ligt   18    Netherlands       82         91
# 229   230621        G. Donnarumma   19          Italy       82         93
# 413   235790           K. Havertz   19        Germany       80         89
# 570   227796           C. Pulisic   19  United States       79         87
# 730   235212            A. Hakimi   19        Morocco       78         86
# 734   231691            A. Lafont   19         France       78         90
# 735   231281  T. Alexander-Arnold   19        England       78         88
# 1004  233049            J. Sancho   18        England       77         89
# 1110  229558         D. Upamecano   19         France       77         88
#
#                      Club   Value   Wage  Special  ... Composure  Marking  \
# 25    Paris Saint-Germain    €81M  €100K     2118  ...      86.0     34.0
# ...

# %%
#Lets find out the best GoalKEeper there is 

data[(data['GKKicking']>85) & (data['GKPositioning']> 85) & (data['GKReflexes']>85) & (data['GKDiving']>=85) & (data['GKHandling']>=85)]
# Out:
#         ID      Name  Age Nationality  Overall  Potential               Club  \
# 3   193080    De Gea   27       Spain       91         93  Manchester United
# 22  167495  M. Neuer   32     Germany       89         89  FC Bayern München
#
#    Value   Wage  Special  ... Composure  Marking  StandingTackle  \
# 3   €72M  €260K     1471  ...      68.0     15.0            21.0
# 22  €38M  €130K     1473  ...      70.0     17.0            10.0
#
#     SlidingTackle GKDiving GKHandling GKKicking GKPositioning  GKReflexes  \
# 3            13.0     90.0       85.0      87.0          88.0        94.0
# 22           11.0     90.0       86.0      91.0          87.0        87.0
#
#    Release Clause
# 3         €138.6M
# 22         €62.7M
#
# [2 rows x 84 columns]
